# %%
import Adam_optimized_EFT_package as Adam

# %%
wilsons = ['cQQ1', 'cQQ8','cQt1', 'cQt8', 'ctt1']
filenames = Adam.create_file(wilsons) + ['EFT_sm.root']
# create filenames (files should be stored in theis form to allow easy access)

# %%
path = 'C:/Users/HP/Documents/data/EFT/'
# path to where files are stored and run_info
all_data = Adam.make_all_data(path, filenames)
# can comment in/ add variables in the main script, which will be created here
# it is here that the weights can also be taken

# %%
run_info = Adam.find_run_info(path)
#run info contains wilson coefficients for each event
plotting = Adam.plotting_vals()
Adam.plot_variables(all_data, run_info, wilsons, 10, plotting)
# Out:
# EFT_sm
# cQQ1=+2.153
# cQQ1=-2.403
# EFT_sm
# cQQ1=+2.153
# cQQ1=-2.403
# EFT_sm
# cQQ1=+2.153
# cQQ1=-2.403
# EFT_sm
# cQQ1=+2.153
# cQQ1=-2.403
# EFT_sm
# cQQ8=+6.533
# cQQ8=-7.196
# EFT_sm
# cQQ8=+6.533
# cQQ8=-7.196
# EFT_sm
# cQQ8=+6.533
# cQQ8=-7.196
# EFT_sm
# cQQ8=+6.533
# cQQ8=-7.196
# EFT_sm
# cQt1=+1.958
# cQt1=-1.945
# EFT_sm
# cQt1=+1.958
# cQt1=-1.945
# EFT_sm
# cQt1=+1.958
# cQt1=-1.945
# EFT_sm
# cQt1=+1.958
# cQt1=-1.945
# EFT_sm
# cQt8=+3.607
# cQt8=-4.415
# EFT_sm
# cQt8=+3.607
# cQt8=-4.415
# EFT_sm
# cQt8=+3.607
# cQt8=-4.415
# EFT_sm
# cQt8=+3.607
# cQt8=-4.415
# EFT_sm
# ctt1=+1.07
# ctt1=-1.201
# EFT_sm
# ctt1=+1.07
# ctt1=-1.201
# EFT_sm
# ctt1=+1.07
# ctt1=-1.201
# EFT_sm
# ctt1=+1.07
# ctt1=-1.201

# %%
for wilson in wilsons:
    Adam.plot_quad(run_info, wilson, 0.017)

# %%
all_data['EFT_cQQ1_higher'].keys()
# Out:
# dict_keys(['Ht', 'M_tttt', 'max_eta_ttbar', 'leading_pt_b4'])

# %%
vars = ['Ht', 'M_tttt', 'max_eta_ttbar', 'leading_pt_b4']
global_coefs = Adam.find_coefs(all_data, vars, run_info, 'cQQ1', plotting, 10)

# %%
target_hists = Adam.form_hists(all_data, vars, global_coefs, run_info, 0.3, 10, plotting, True)

# %%
a = Adam.general(target_hists, vars, global_coefs, 'cQQ1', 10, plotting)
# Out:
# value of coefficient found as 0.42216+- 0.04516 with a chi squared of 19.129
# value of coefficient found as 0.42216 +0.06112 -0.06715 with a chi squared of 19.129
# value of coefficient found as 0.42216 +0.11758 -0.14255 (95%) with a chi squared of 19.129
